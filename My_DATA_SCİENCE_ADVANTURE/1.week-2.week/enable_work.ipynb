# %%
import pandas as pd

# %%
df1=pd.DataFrame([("yavuz selim","özkök","25","yavuzselimozkok@gmail.com","Enginerr"),
              ("ali","ahmet","45","ahmet@gmail.com","nurse")],columns=["name","surname","age","mails","status"])

# %%
df2=pd.DataFrame({"Names":["yavuz selim","hasan ali","cevdet"],
                  "Surnames":["ozkok","yılmaz","kesan"],
                  "ages":["25","40","55"]})
df2
# Out:
#          Names Surnames ages
# 0  yavuz selim    ozkok   25
# 1    hasan ali   yılmaz   40
# 2       cevdet    kesan   55

# %%
df3=pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv")
df3
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df3.shape
# Out:
# (76, 9)

# %%
df3.describe
# Out:
# <bound method NDFrame.describe of     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# ...

# %%
df3
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df3["Major"] #belirlediğim major code da başında
# Out:
# 0                             PETROLEUM ENGINEERING
# 1                    MINING AND MINERAL ENGINEERING
# 2                         METALLURGICAL ENGINEERING
# 3         NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                               NUCLEAR ENGINEERING
#                           ...
# 71                                          ECOLOGY
# 72                    TREATMENT THERAPY PROFESSIONS
# 73              GENERAL MEDICAL AND HEALTH SERVICES
# 74    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df3.set_index("Rank")
# Out:
#       Major_code                                          Major  \
# Rank
# 1           2419                          PETROLEUM ENGINEERING
# 2           2416                 MINING AND MINERAL ENGINEERING
# 3           2415                      METALLURGICAL ENGINEERING
# 4           2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 5           2418                            NUCLEAR ENGINEERING
# ...          ...                                            ...
# 72          3604                                        ECOLOGY
# 73          6109                  TREATMENT THERAPY PROFESSIONS
# 74          6100            GENERAL MEDICAL AND HEALTH SERVICES
# 75          6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 76          3609                                        ZOOLOGY
#
#               Major_category  Total    Men  Women  ShareWomen  Median
# Rank
# 1                Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df3
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df3.loc[1:10,"Major"] #set index olarak belirlediğim rank verisini loc içinde bu şekilde kullandım
# Out:
# 1                MINING AND MINERAL ENGINEERING
# 2                     METALLURGICAL ENGINEERING
# 3     NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                           NUCLEAR ENGINEERING
# 5                          CHEMICAL ENGINEERING
# 6                    ASTRONOMY AND ASTROPHYSICS
# 7                        MECHANICAL ENGINEERING
# 8                         AEROSPACE ENGINEERING
# 9                        ELECTRICAL ENGINEERING
# 10                         COMPUTER ENGINEERING
# Name: Major, dtype: object

# %%
df3.loc[1:5,["Men","Women","Median"]]
# Out:
#      Men  Women  Median
# 1    679     77   75000
# 2    725    131   73000
# 3   1123    135   70000
# 4   2200    373   65000
# 5  21239  11021   65000

# %%
df3.iloc[:5]
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df3.iloc[:5,:3]
# Out:
#    Rank  Major_code                                      Major
# 0     1        2419                      PETROLEUM ENGINEERING
# 1     2        2416             MINING AND MINERAL ENGINEERING
# 2     3        2415                  METALLURGICAL ENGINEERING
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4     5        2418                        NUCLEAR ENGINEERING

# %%
df3.iloc[1:5,1]
# Out:
# 1    2416
# 2    2415
# 3    2417
# 4    2418
# Name: Major_code, dtype: int64

# %%
df3[df3["Major"]=="NUCLEAR ENGINEERING"] #işte bu artık istediğim satırda istediğim indeksteki veriyi özgürce çekebilirim
# Out:
#    Rank  Major_code                Major Major_category  Total   Men  Women  \
# 4     5        2418  NUCLEAR ENGINEERING    Engineering   2573  2200    373
#
#    ShareWomen  Median
# 4    0.144967   65000

# %%
df3[df3["ShareWomen"]>.5] #bu gibi operasyonel işler yapılır
# Out:
#     Rank  Major_code                                              Major  \
# 6      7        5001                         ASTRONOMY AND ASTROPHYSICS
# 26    27        6107                                            NURSING
# 28    29        5102  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 34    35        3702                    STATISTICS AND DECISION SCIENCE
# 35    36        3607                                       PHARMACOLOGY
# 36    37        6105                   MEDICAL TECHNOLOGIES TECHNICIANS
# 37    38        5006                                       OCEANOGRAPHY
# 40    41        6104                         MEDICAL ASSISTING SERVICES
# 42    43        4006                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 47    48        3605                                           GENETICS
# 48    49        3603                                  MOLECULAR BIOLOGY
# 49    50        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# ...

# %%
df3[(df3["ShareWomen"]>0.5) & ((df3["Major"] == "BIOLOGY") | (df3["Major"] == "ECOLOGY"))] #bu işi çözdük aga
# Out:
#     Rank  Major_code    Major          Major_category   Total     Men   Women  \
# 70    71        3600  BIOLOGY  Biology & Life Science  280709  111762  168947
# 71    72        3604  ECOLOGY  Biology & Life Science    9154    3878    5276
#
#     ShareWomen  Median
# 70    0.601858   33400
# 71    0.576360   33000

# %%
df3
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            76 non-null     int64
#  1   Major_code      76 non-null     int64
#  2   Major           76 non-null     object
#  3   Major_category  76 non-null     object
#  4   Total           76 non-null     int64
#  5   Men             76 non-null     int64
#  6   Women           76 non-null     int64
#  7   ShareWomen      76 non-null     float64
#  8   Median          76 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 5.5+ KB

# %%
df3["Major_code"].describe()
# Out:
# count      76.000000
# mean     3580.026316
# std      1437.455038
# min      1301.000000
# 25%      2409.750000
# 50%      3601.500000
# 75%      5002.250000
# max      6199.000000
# Name: Major_code, dtype: float64

# %%
df3["Rank"].describe()  #liste içinden rank değerini belirleyip basar
# Out:
# count    76.000000
# mean     38.500000
# std      22.083176
# min       1.000000
# 25%      19.750000
# 50%      38.500000
# 75%      57.250000
# max      76.000000
# Name: Rank, dtype: float64

# %%
df3["Major_category"].value_counts(normalize=True) #sahip olduğu categoric verilerin değerin
# Out:
# Engineering                0.381579
# Biology & Life Science     0.184211
# Health                     0.157895
# Computers & Mathematics    0.144737
# Physical Sciences          0.131579
# Name: Major_category, dtype: float64

# %%
df3["ShareWomen"].loc[df3["Major_category"]=="Engineering"] #sadece engineering olanların sayısal kısmını verdi
# Out:
# 0     0.120564
# 1     0.101852
# 2     0.153037
# 3     0.107313
# 4     0.144967
# 5     0.341631
# 7     0.119559
# 8     0.139793
# 9     0.196450
# 10    0.199413
# 11    0.310820
# 12    0.437847
# 13    0.183985
# 14    0.320784
# 15    0.343473
# 16    0.252960
# 17    0.350442
# 19    0.292607
# 20    0.325092
# 21    0.189970
# 22    0.227118
# 23    0.251389
# 24    0.322222
# 25    0.342229
# 27    0.249190
# 38    0.174123
# 43    0.077453
# 44    0.200023
# 46    0.451465
# Name: ShareWomen, dtype: float64

# %%
unique_major_categories=df3["Major_category"].unique().tolist() #unice değerleri bir liste haline getirir
unique_major_categories
# Out:
# ['Engineering',
#  'Physical Sciences',
#  'Computers & Mathematics',
#  'Health',
#  'Biology & Life Science']

# %%
df3.isnull().sum()   #eğer içerisinde null değer varsa kontrol edebiliriz
# Out:
# Rank              0
# Major_code        0
# Major             0
# Major_category    0
# Total             0
# Men               0
# Women             0
# ShareWomen        0
# Median            0
# dtype: int64

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       D    Delhi      M            pink
# 4   12       E   Mumbai      M           black
# 5   11       F    Delhi      M           green
# 6   17       G   Mumbai      F             red

# %%
data[data["age"]>16]
# Out:
#    age section    city gender favourite_color
# 1   22       B   Delhi      F            blue
# 3   21       D   Delhi      M            pink
# 6   17       G  Mumbai      F             red

# %%
data['new'] = data['city'].str[:2] #new indeksine city serisindeki verilerin ilk iki harfini kopyaladık

# %%
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       D    Delhi      M            pink
# 4   12       E   Mumbai      M           black
# 5   11       F    Delhi      M           green
# 6   17       G   Mumbai      F             red

# %%
data.set_index("section",inplace=True)

# %%
data
# Out:
#          age     city gender favourite_color
# section
# A         10  Gurgaon      M             red
# B         22    Delhi      F            blue
# C         13   Mumbai      F          yellow
# D         21    Delhi      M            pink
# E         12   Mumbai      M           black
# F         11    Delhi      M           green
# G         17   Mumbai      F             red

# %%
data.iloc[1]
# Out:
# age                   22
# city               Delhi
# gender                 F
# favourite_color     blue
# Name: B, dtype: object

# %%
data.loc[["D","E"],["city","gender"]]
# Out:
#            city gender
# section
# D         Delhi      M
# E        Mumbai      M

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'country' : [ 'USA', 'GBR', 'TUR', 'NLD', 'BEL', 'DEU', 'FRA'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})
data.set_index('section', inplace=True)
data
# Out:
#          age country gender favourite_color
# section
# A         10     USA      M             red
# B         22     GBR      F            blue
# C         13     TUR      F          yellow
# D         21     NLD      M            pink
# E         12     BEL      M           black
# F         11     DEU      M           green
# G         17     FRA      F             red

# %%
data[data["age"]>15]["country"]
# Out:
# section
# B    GBR
# D    NLD
# G    FRA
# Name: country, dtype: object

# %%
data[(data['age']>15) & (data['favourite_color'] == 'red')]
# Out:
#          age country gender favourite_color
# section
# G         17     FRA      F             red

# %%
import numpy as np
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data.loc["A2","X"]
# Out:
# 1   -0.848077
# 2   -2.018168
# 3    0.528813
# Name: X, dtype: float64

# %%
drinks=pd.read_csv("http://bit.ly/drinksbycountry")

# %%
drinks[drinks["country"]=="Afghanistan"]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia

# %%
drinks.loc[2:5,"wine_servings"]
# Out:
# 2     14
# 3    312
# 4     45
# 5     45
# Name: wine_servings, dtype: int64

# %%
drinks.groupby("continent").beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent=="Africa"].beer_servings.mean() #group by sız hali bu şekilde
# Out:
# 61.471698113207545

# %%
drinks.groupby("continent").beer_servings.agg(["mean","max","min","count"])
# Out:
#                      mean  max  min  count
# continent
# Africa          61.471698  376    0     53
# Asia            37.045455  247    0     44
# Europe         193.777778  361    0     45
# North America  145.434783  285    1     23
# Oceania         89.687500  306    0     16
# South America  175.083333  333   93     12

# %%
# %matplotlib inline

# %%
drinks.groupby("continent").mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='continent'>
